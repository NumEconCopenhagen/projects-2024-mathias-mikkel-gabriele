# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - 1. [Problem 1: Production economy and CO2 taxation](#toc1_)
# - 2. [Problem 2: Career choice model](#toc2_)
# - 3. [Problem 3: Barycentric interpolation](#toc3_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=false
# 	minLevel=2
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %%
# Write your code here
import numpy as np
import matplotlib.pyplot as plt
from types import SimpleNamespace

# %load_ext autoreload
# %autoreload 2
from examproject import CareerClass
from ProductionCO2Class import ProductionCO2Class
import examproject as ep
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = ProductionCO2Class()

# %% [markdown]
# ## 1. <a id='toc1_'></a>[Problem 1: Production economy and CO2 taxation](#toc0_)

# %% [markdown]
# Consider a production economy with two firms indexed by $j \in \{1,2\}$. Each produce its own good. They solve
#
# $$
# \begin{align*}
# \max_{y_{j}}\pi_{j}&=p_{j}y_{j}-w_{j}\ell_{j}\\\text{s.t.}\;&y_{j}=A\ell_{j}^{\gamma}.
# \end{align*}
# $$
#
# Optimal firm behavior is
#
# $$
# \begin{align*}
# \ell_{j}^{\star}(w,p_{j})&=\left(\frac{p_{j}A\gamma}{w}\right)^{\frac{1}{1-\gamma}} \\
# y_{j}^{\star}(w,p_{j})&=A\left(\ell_{j}^{\star}(w,p_{j})\right)^{\gamma}
# \end{align*}
# $$
#
# The implied profits are
#
# $$
# \pi_{j}^*(w,p_{j})=\frac{1-\gamma}{\gamma}w\cdot\left(\frac{p_{j}A\gamma}{w}\right)^{\frac{1}{1-\gamma}}
# $$
#
# A single consumer supplies labor, and consumes the goods the firms produce. She also recieves the implied profits of the firm.<br>
# She solves:
#
# $$
# \begin{align*}
# U(p_1,p_2,w,\tau,T) = \max_{c_{1},c_{2},\ell} & \log(c_{1}^{\alpha}c_{2}^{1-\alpha})-\nu\frac{\ell^{1+\epsilon}}{1+\epsilon} \\
# \text{s.t.}\,\,\,&p_{1}c_{1}+(p_{2}+\tau)c_{2}=w\ell+T+\pi_{1}^*(w,p_{1})+\pi_{2}^*(w,p_{2})
# \end{align*}
# $$
#
# where $\tau$ is a tax and $T$ is lump-sum transfer. <br>
# For a given $\ell$, it can be shown that optimal behavior is
#
# $$
# \begin{align*}
# c_{1}(\ell)&=\alpha\frac{w\ell+T+\pi_{1}^*(w,p_{1})+\pi_{2}^*(w,p_{2})}{p_{1}} \\
# c_{2}(\ell)&=(1-\alpha)\frac{w\ell+T+\pi_{1}^*(w,p_{1})+\pi_{2}^*(w,p_{2})}{p_{2}+\tau} \\
# \end{align*}
# $$
# Such that optimal behavior is:
# $$
# \ell^* = \underset{\ell}{\arg\max} \log(\left(c_{1}(\ell)\right)^{\alpha}\cdot \left(c_{2}(\ell)\right)^{1-\alpha})-\nu\frac{\ell^{1+\epsilon}}{1+\epsilon}
# $$
# With optimal consumption:
# $$
# \begin{align*}
# c_1^*=c_{1}(\ell^*) \\
# c_2^*=c_{2}(\ell^*)\\
# \end{align*}
# $$
#
#
# The government chooses $\tau$ and balances its budget so $T=\tau c_2^*$. We initially set $\tau,T=0$.
#
# Market clearing requires:
#
# 1. Labor market: $\ell^* = \ell_1^* + \ell_2^*$
# 1. Good market 1: $c_1^* = y_1^*$
# 1. Good market 2: $c_2^* = y_2^*$

# %% [markdown]
# **Question 1:** Check market clearing conditions for $p_1$ in `linspace(0.1,2.0,10)` and $p_2$ in `linspace(0.1,2.0,10)`. We choose $w=1$ as numeraire.

# %%
for p1 in np.linspace(0.1,2.0,10):
    for p2 in np.linspace(0.1,2.0,10):
        model.evaluate_equilibrium([p1,p2], do_print=True)
# Out:
# For p1=0.1000, p2=0.1000
# Market clearing errors are:
# Good1: 2.964982
# Good2: 6.984958
# Labor market: 0.994994
# ------------------------------------
# For p1=0.1000, p2=0.3111
# Market clearing errors are:
# Good1: 3.030075
# Good2: 2.154500
# Labor market: 0.973297
# ------------------------------------
# For p1=0.1000, p2=0.5222
# Market clearing errors are:
# Good1: 3.162019
# Good2: 1.174046
# Labor market: 0.929315
# ------------------------------------
# For p1=0.1000, p2=0.7333
# Market clearing errors are:
# Good1: 3.360815
# Good2: 0.718593
# Labor market: 0.863050
# ------------------------------------
# For p1=0.1000, p2=0.9444
# Market clearing errors are:
# Good1: 3.626464
# Good2: 0.436081
# Labor market: 0.774500
# ------------------------------------
# For p1=0.1000, p2=1.1556
# Market clearing errors are:
# Good1: 3.958964
# Good2: 0.231724
# Labor market: 0.663667
# ------------------------------------
# For p1=0.1000, p2=1.3667
# Market clearing errors are:
# Good1: 4.358315
# Good2: 0.069306
# Labor market: 0.530550
# ------------------------------------
# For p1=0.1000, p2=1.5778
# Market clearing errors are:
# Good1: 4.824519
# Good2: -0.068009
# Labor market: 0.375148
# ------------------------------------
# For p1=0.1000, p2=1.7889
# Market clearing errors are:
# Good1: 5.357575
# Good2: -0.189109
# Labor market: 0.197463
# ------------------------------------
# For p1=0.1000, p2=2.0000
# Market clearing errors are:
# Good1: 5.957482
# Good2: -0.299127
# Labor market: -0.002506
# ------------------------------------
# For p1=0.3111, p2=0.1000
# Market clearing errors are:
# Good1: 0.834468
# Good2: 7.136841
# Labor market: 0.973297
# ------------------------------------
# For p1=0.3111, p2=0.3111
# Market clearing errors are:
# Good1: 0.855391
# Good2: 2.203320
# Labor market: 0.951599
# ------------------------------------
# For p1=0.3111, p2=0.5222
# Market clearing errors are:
# Good1: 0.897802
# Good2: 1.203130
# Labor market: 0.907617
# ------------------------------------
# For p1=0.3111, p2=0.7333
# Market clearing errors are:
# Good1: 0.961701
# Good2: 0.739304
# Labor market: 0.841352
# ------------------------------------
# For p1=0.3111, p2=0.9444
# Market clearing errors are:
# Good1: 1.047088
# Good2: 0.452162
# Labor market: 0.752803
# ------------------------------------
# For p1=0.3111, p2=1.1556
# Market clearing errors are:
# Good1: 1.153963
# Good2: 0.244868
# Labor market: 0.641969
# ------------------------------------
# For p1=0.3111, p2=1.3667
# Market clearing errors are:
# Good1: 1.282326
# Good2: 0.080419
# Labor market: 0.508852
# ------------------------------------
# For p1=0.3111, p2=1.5778
# Market clearing errors are:
# Good1: 1.432177
# Good2: -0.058383
# Labor market: 0.353451
# ------------------------------------
# For p1=0.3111, p2=1.7889
# Market clearing errors are:
# Good1: 1.603516
# Good2: -0.180618
# Labor market: 0.175766
# ------------------------------------
# For p1=0.3111, p2=2.0000
# Market clearing errors are:
# Good1: 1.796343
# Good2: -0.291533
# Labor market: -0.024203
# ------------------------------------
# For p1=0.5222, p2=0.1000
# Market clearing errors are:
# Good1: 0.353956
# Good2: 7.444711
# Labor market: 0.929315
# ------------------------------------
# For p1=0.5222, p2=0.3111
# Market clearing errors are:
# Good1: 0.366421
# Good2: 2.302278
# Labor market: 0.907617
# ------------------------------------
# For p1=0.5222, p2=0.5222
# Market clearing errors are:
# Good1: 0.391687
# Good2: 1.262084
# Labor market: 0.863636
# ------------------------------------
# For p1=0.5222, p2=0.7333
# Market clearing errors are:
# Good1: 0.429754
# Good2: 0.781286
# Labor market: 0.797371
# ------------------------------------
# For p1=0.5222, p2=0.9444
# Market clearing errors are:
# Good1: 0.480623
# Good2: 0.484760
# Labor market: 0.708821
# ------------------------------------
# For p1=0.5222, p2=1.1556
# Market clearing errors are:
# Good1: 0.544293
# Good2: 0.271511
# Labor market: 0.597988
# ------------------------------------
# For p1=0.5222, p2=1.3667
# Market clearing errors are:
# Good1: 0.620765
# Good2: 0.102946
# Labor market: 0.464871
# ------------------------------------
# For p1=0.5222, p2=1.5778
# Market clearing errors are:
# Good1: 0.710038
# Good2: -0.038870
# Labor market: 0.309469
# ------------------------------------
# For p1=0.5222, p2=1.7889
# Market clearing errors are:
# Good1: 0.812112
# Good2: -0.163408
# Labor market: 0.131784
# ------------------------------------
# For p1=0.5222, p2=2.0000
# Market clearing errors are:
# Good1: 0.926988
# Good2: -0.276139
# Labor market: -0.068185
# ------------------------------------
# For p1=0.7333, p2=0.1000
# Market clearing errors are:
# Good1: 0.098445
# Good2: 7.908569
# Labor market: 0.863050
# ------------------------------------
# For p1=0.7333, p2=0.3111
# Market clearing errors are:
# Good1: 0.107321
# Good2: 2.451375
# Labor market: 0.841352
# ------------------------------------
# For p1=0.7333, p2=0.5222
# Market clearing errors are:
# Good1: 0.125313
# Good2: 1.350908
# Labor market: 0.797371
# ------------------------------------
# For p1=0.7333, p2=0.7333
# Market clearing errors are:
# Good1: 0.152422
# Good2: 0.844540
# Labor market: 0.731105
# ------------------------------------
# For p1=0.7333, p2=0.9444
# Market clearing errors are:
# Good1: 0.188647
# Good2: 0.533875
# Labor market: 0.642556
# ------------------------------------
# For p1=0.7333, p2=1.1556
# Market clearing errors are:
# Good1: 0.233987
# Good2: 0.311652
# Labor market: 0.531722
# ------------------------------------
# For p1=0.7333, p2=1.3667
# Market clearing errors are:
# Good1: 0.288445
# Good2: 0.136887
# Labor market: 0.398605
# ------------------------------------
# For p1=0.7333, p2=1.5778
# Market clearing errors are:
# Good1: 0.352018
# Good2: -0.009471
# Labor market: 0.243204
# ------------------------------------
# For p1=0.7333, p2=1.7889
# Market clearing errors are:
# Good1: 0.424707
# Good2: -0.137478
# Labor market: 0.065519
# ------------------------------------
# For p1=0.7333, p2=2.0000
# Market clearing errors are:
# Good1: 0.506513
# Good2: -0.252947
# Labor market: -0.134450
# ------------------------------------
# For p1=0.9444, p2=0.1000
# Market clearing errors are:
# Good1: -0.082950
# Good2: 8.528415
# Labor market: 0.774500
# ------------------------------------
# For p1=0.9444, p2=0.3111
# Market clearing errors are:
# Good1: -0.076057
# Good2: 2.650612
# Labor market: 0.752803
# ------------------------------------
# For p1=0.9444, p2=0.5222
# Market clearing errors are:
# Good1: -0.062087
# Good2: 1.469602
# Labor market: 0.708821
# ------------------------------------
# For p1=0.9444, p2=0.7333
# Market clearing errors are:
# Good1: -0.041038
# Good2: 0.929064
# Labor market: 0.642556
# ------------------------------------
# For p1=0.9444, p2=0.9444
# Market clearing errors are:
# Good1: -0.012910
# Good2: 0.599505
# Labor market: 0.554006
# ------------------------------------
# For p1=0.9444, p2=1.1556
# Market clearing errors are:
# Good1: 0.022295
# Good2: 0.365293
# Labor market: 0.443173
# ------------------------------------
# For p1=0.9444, p2=1.3667
# Market clearing errors are:
# Good1: 0.064580
# Good2: 0.182242
# Labor market: 0.310056
# ------------------------------------
# For p1=0.9444, p2=1.5778
# Market clearing errors are:
# Good1: 0.113943
# Good2: 0.029815
# Labor market: 0.154655
# ------------------------------------
# For p1=0.9444, p2=1.7889
# Market clearing errors are:
# Good1: 0.170384
# Good2: -0.102828
# Labor market: -0.023031
# ------------------------------------
# For p1=0.9444, p2=2.0000
# Market clearing errors are:
# Good1: 0.233903
# Good2: -0.221954
# Labor market: -0.223000
# ------------------------------------
# For p1=1.1556, p2=0.1000
# Market clearing errors are:
# Good1: -0.230848
# Good2: 9.304248
# Labor market: 0.663667
# ------------------------------------
# For p1=1.1556, p2=0.3111
# Market clearing errors are:
# Good1: -0.225215
# Good2: 2.899987
# Labor market: 0.641969
# ------------------------------------
# For p1=1.1556, p2=0.5222
# Market clearing errors are:
# Good1: -0.213797
# Good2: 1.618166
# Labor market: 0.597988
# ------------------------------------
# For p1=1.1556, p2=0.7333
# Market clearing errors are:
# Good1: -0.196593
# Good2: 1.034860
# Labor market: 0.531722
# ------------------------------------
# For p1=1.1556, p2=0.9444
# Market clearing errors are:
# Good1: -0.173605
# Good2: 0.681652
# Labor market: 0.443173
# ------------------------------------
# For p1=1.1556, p2=1.1556
# Market clearing errors are:
# Good1: -0.144831
# Good2: 0.432432
# Labor market: 0.332340
# ------------------------------------
# For p1=1.1556, p2=1.3667
# Market clearing errors are:
# Good1: -0.110271
# Good2: 0.239010
# Labor market: 0.199222
# ------------------------------------
# For p1=1.1556, p2=1.5778
# Market clearing errors are:
# Good1: -0.069927
# Good2: 0.078988
# Labor market: 0.043821
# ------------------------------------
# For p1=1.1556, p2=1.7889
# Market clearing errors are:
# Good1: -0.023797
# Good2: -0.059459
# Labor market: -0.133864
# ------------------------------------
# For p1=1.1556, p2=2.0000
# Market clearing errors are:
# Good1: 0.028118
# Good2: -0.183163
# Labor market: -0.333833
# ------------------------------------
# For p1=1.3667, p2=0.1000
# Market clearing errors are:
# Good1: -0.360774
# Good2: 10.236069
# Labor market: 0.530550
# ------------------------------------
# For p1=1.3667, p2=0.3111
# Market clearing errors are:
# Good1: -0.356011
# Good2: 3.199500
# Labor market: 0.508852
# ------------------------------------
# For p1=1.3667, p2=0.5222
# Market clearing errors are:
# Good1: -0.346356
# Good2: 1.796600
# Labor market: 0.464871
# ------------------------------------
# For p1=1.3667, p2=0.7333
# Market clearing errors are:
# Good1: -0.331810
# Good2: 1.161926
# Labor market: 0.398605
# ------------------------------------
# For p1=1.3667, p2=0.9444
# Market clearing errors are:
# Good1: -0.312373
# Good2: 0.780316
# Labor market: 0.310056
# ------------------------------------
# For p1=1.3667, p2=1.1556
# Market clearing errors are:
# Good1: -0.288043
# Good2: 0.513071
# Labor market: 0.199222
# ------------------------------------
# For p1=1.3667, p2=1.3667
# Market clearing errors are:
# Good1: -0.258822
# Good2: 0.307192
# Labor market: 0.066105
# ------------------------------------
# For p1=1.3667, p2=1.5778
# Market clearing errors are:
# Good1: -0.224710
# Good2: 0.138047
# Labor market: -0.089296
# ------------------------------------
# For p1=1.3667, p2=1.7889
# Market clearing errors are:
# Good1: -0.185706
# Good2: -0.007369
# Labor market: -0.266981
# ------------------------------------
# For p1=1.3667, p2=2.0000
# Market clearing errors are:
# Good1: -0.141810
# Good2: -0.136572
# Labor market: -0.466950
# ------------------------------------
# For p1=1.5778, p2=0.1000
# Market clearing errors are:
# Good1: -0.479940
# Good2: 11.323878
# Labor market: 0.375148
# ------------------------------------
# For p1=1.5778, p2=0.3111
# Market clearing errors are:
# Good1: -0.475815
# Good2: 3.549153
# Labor market: 0.353451
# ------------------------------------
# For p1=1.5778, p2=0.5222
# Market clearing errors are:
# Good1: -0.467452
# Good2: 2.004903
# Labor market: 0.309469
# ------------------------------------
# For p1=1.5778, p2=0.7333
# Market clearing errors are:
# Good1: -0.454852
# Good2: 1.310264
# Labor market: 0.243204
# ------------------------------------
# For p1=1.5778, p2=0.9444
# Market clearing errors are:
# Good1: -0.438016
# Good2: 0.895496
# Labor market: 0.154655
# ------------------------------------
# For p1=1.5778, p2=1.1556
# Market clearing errors are:
# Good1: -0.416942
# Good2: 0.607208
# Labor market: 0.043821
# ------------------------------------
# For p1=1.5778, p2=1.3667
# Market clearing errors are:
# Good1: -0.391631
# Good2: 0.386788
# Labor market: -0.089296
# ------------------------------------
# For p1=1.5778, p2=1.5778
# Market clearing errors are:
# Good1: -0.362083
# Good2: 0.206993
# Labor market: -0.244697
# ------------------------------------
# For p1=1.5778, p2=1.7889
# Market clearing errors are:
# Good1: -0.328297
# Good2: 0.053440
# Labor market: -0.422383
# ------------------------------------
# For p1=1.5778, p2=2.0000
# Market clearing errors are:
# Good1: -0.290275
# Good2: -0.082181
# Labor market: -0.622352
# ------------------------------------
# For p1=1.7889, p2=0.1000
# Market clearing errors are:
# Good1: -0.592158
# Good2: 12.567674
# Labor market: 0.197463
# ------------------------------------
# For p1=1.7889, p2=0.3111
# Market clearing errors are:
# Good1: -0.588519
# Good2: 3.948945
# Labor market: 0.175766
# ------------------------------------
# For p1=1.7889, p2=0.5222
# Market clearing errors are:
# Good1: -0.581143
# Good2: 2.243077
# Labor market: 0.131784
# ------------------------------------
# For p1=1.7889, p2=0.7333
# Market clearing errors are:
# Good1: -0.570030
# Good2: 1.479872
# Labor market: 0.065519
# ------------------------------------
# For p1=1.7889, p2=0.9444
# Market clearing errors are:
# Good1: -0.555180
# Good2: 1.027192
# Labor market: -0.023031
# ------------------------------------
# For p1=1.7889, p2=1.1556
# Market clearing errors are:
# Good1: -0.536593
# Good2: 0.714844
# Labor market: -0.133864
# ------------------------------------
# For p1=1.7889, p2=1.3667
# Market clearing errors are:
# Good1: -0.514269
# Good2: 0.477797
# Labor market: -0.266981
# ------------------------------------
# For p1=1.7889, p2=1.5778
# Market clearing errors are:
# Good1: -0.488208
# Good2: 0.285825
# Labor market: -0.422383
# ------------------------------------
# For p1=1.7889, p2=1.7889
# Market clearing errors are:
# Good1: -0.458410
# Good2: 0.122969
# Labor market: -0.600068
# ------------------------------------
# For p1=1.7889, p2=2.0000
# Market clearing errors are:
# Good1: -0.424875
# Good2: -0.019991
# Labor market: -0.800037
# ------------------------------------
# For p1=2.0000, p2=0.1000
# Market clearing errors are:
# Good1: -0.699626
# Good2: 13.967458
# Labor market: -0.002506
# ------------------------------------
# For p1=2.0000, p2=0.3111
# Market clearing errors are:
# Good1: -0.696371
# Good2: 4.398875
# Labor market: -0.024203
# ------------------------------------
# For p1=2.0000, p2=0.5222
# Market clearing errors are:
# Good1: -0.689774
# Good2: 2.511121
# Labor market: -0.068185
# ------------------------------------
# For p1=2.0000, p2=0.7333
# Market clearing errors are:
# Good1: -0.679834
# Good2: 1.670752
# Labor market: -0.134450
# ------------------------------------
# For p1=2.0000, p2=0.9444
# Market clearing errors are:
# Good1: -0.666552
# Good2: 1.175404
# Labor market: -0.223000
# ------------------------------------
# For p1=2.0000, p2=1.1556
# Market clearing errors are:
# Good1: -0.649927
# Good2: 0.835979
# Labor market: -0.333833
# ------------------------------------
# For p1=2.0000, p2=1.3667
# Market clearing errors are:
# Good1: -0.629959
# Good2: 0.580221
# Labor market: -0.466950
# ------------------------------------
# For p1=2.0000, p2=1.5778
# Market clearing errors are:
# Good1: -0.606649
# Good2: 0.374544
# Labor market: -0.622352
# ------------------------------------
# For p1=2.0000, p2=1.7889
# Market clearing errors are:
# Good1: -0.579996
# Good2: 0.201217
# Labor market: -0.800037
# ------------------------------------
# For p1=2.0000, p2=2.0000
# Market clearing errors are:
# Good1: -0.550001
# Good2: 0.049998
# Labor market: -1.000006
# ------------------------------------

# %% [markdown]
# **Question 2:** Find the equilibrium prices $p_1$ and $p_2$.<br>
# *Hint: you can use Walras' law to only check 2 of the market clearings*

# %% [markdown]
# Assume the government care about the social welfare function:
#
# $$
# SWF = U - \kappa y_2^*
# $$

# %% [markdown]
# Here $\kappa$ measures the social cost of carbon emitted by the production of $y_2$ in equilibrium.

# %%
model.find_prices(do_print=True)
# Out:
# For p1=1.0954, p2=1.6733
# Market clearing errors are:
# Good1: 0.000008
# Good2: -0.000017
# Labor market: -0.000020
# ------------------------------------

# %% [markdown]
# **Question 3:** What values of $\tau$ and (implied) $T$ should the government choose to maximize $SWF$?

# %%
model.find_optimal_tau()
# Out:
# Evaluating social welfare function at tau=0.3820
# U=-0.66
# y2=0.84
# SWF=-0.74
# Evaluating social welfare function at tau=0.6180
# U=-0.67
# y2=0.81
# SWF=-0.75
# Evaluating social welfare function at tau=0.2361
# U=-0.63
# y2=0.80
# SWF=-0.71
# Evaluating social welfare function at tau=0.1459
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2293
# U=-0.64
# y2=0.83
# SWF=-0.72
# Evaluating social welfare function at tau=0.2918
# U=-0.64
# y2=0.82
# SWF=-0.73
# Evaluating social welfare function at tau=0.2574
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2442
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2392
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2335
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2373
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2351
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2365
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2357
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2362
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2359
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2361
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2360
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2361
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2360
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2361
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2361
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2361
# U=-0.64
# y2=0.82
# SWF=-0.72
# Evaluating social welfare function at tau=0.2361
# U=-0.64
# y2=0.82
# SWF=-0.72
# Optimal tau: 0.2361
# Associated T: 0.1934
# 0.2360679774997897

# %% [markdown]
# ## 2. <a id='toc2_'></a>[Problem 2: Career choice model](#toc0_)

# %% [markdown]
# Consider a graduate $i$ making a choice between entering $J$ different career tracks. <br>
# Entering career $j$ yields utility $u^k_{ij}$. This value is unknown to the graduate ex ante, but will ex post be: <br>
# $$
#     u_{i,j}^k = v_{j} + \epsilon_{i,j}^k
# $$
#
# They know that $\epsilon^k_{i,j}\sim \mathcal{N}(0,\sigma^2)$, but they do not observe $\epsilon^k_{i,j}$ before making their career choice. <br>

# %% [markdown]
# Consider the concrete case of $J=3$ with:
# $$
# \begin{align*}
#     v_{1} &= 1 \\
#     v_{2} &= 2 \\
#     v_{3} &= 3
# \end{align*}
# $$

# %% [markdown]
# If the graduates know the values of $v_j$ and the distribution of $\epsilon_{i,j}^k$, they can calculate the expected utility of each career track using simulation: <br>
# $$
#     \mathbb{E}\left[ u^k_{i,j}\vert v_j \right] \approx v_j + \frac{1}{K}\sum_{k=1}^K \epsilon_{i,j}^k
# $$

# %%
par = SimpleNamespace()
par.J = 3
par.N = 10
par.K = 10000

par.F = np.arange(1,par.N+1)
par.sigma = 2

par.v = np.array([1,2,3])
par.c = 1

# %% [markdown]
# **Question 1:** Simulate and calculate expected utility and the average realised utility for $K=10000$ draws, for each career choice $j$.

# %%
# draw for random normal distribution
par.mu = 0
par.sigma = 1

draw = np.random.normal(par.mu, par.sigma, par.K)

# %%
# initialize class
career = CareerClass()

seed = 2024
# check what the sum of 10.000 draws from a standard normal distribution is when using seed=2024
print (f'The sum of 10.000 draws from a standard normal distribution using seed=2024 is {career.simulate(seed=seed):.2f}')

# calculate the expected utility for each career path
for v in par.v:
    print (f'The expected utility for career path {v} is {career.expec_utility(v, seed):.2f}')

# calculate average realised utility
career.avg_real_utility(1, seed), career.avg_real_utility(2, seed), career.avg_real_utility(3, seed)
# Out:
# The sum of 10.000 draws from a standard normal distribution using seed=2024 is 153.92
# The expected utility for career path 1 is 1.02
# The expected utility for career path 2 is 2.02
# The expected utility for career path 3 is 3.02
# (1.0153916595866397, 2.015391659586645, 3.015391659586654)

# %% [markdown]
# Now consider a new scenario: Imagine that the graduate does not know $v_j$. The *only* prior information they have on the value of each job, comes from their $F_{i}$ friends that work in each career $j$. After talking with them, they know the average utility of their friends (which includes their friends' noise term), giving them the prior expecation: <br>
# $$
# \tilde{u}^k_{i,j}\left( F_{i}\right) = \frac{1}{F_{i}}\sum_{f=1}^{F_{i}} \left(v_{j} + \epsilon^k_{f,j}\right), \; \epsilon^k_{f,j}\sim \mathcal{N}(0,\sigma^2)
# $$
# For ease of notation consider that each graduate have $F_{i}=i$ friends in each career. <br>

# %% [markdown]
# For $K$ times do the following: <br>
# 1. For each person $i$ draw $J\cdot F_i$ values of $\epsilon_{f,j}^{k}$, and calculate the prior expected utility of each career track, $\tilde{u}^k_{i,j}\left( F_{i}\right)$. <br>
# Also draw their own $J$ noise terms, $\epsilon_{i,j}^k$
# 1. Each person $i$ chooses the career track with the highest expected utility: $$j_i^{k*}= \arg\max_{j\in{1,2\dots,J}}\left\{ \tilde{u}^k_{i,j}\left( F_{i}\right)\right\} $$
# 1. Store the chosen careers: $j_i^{k*}$, the prior expectation of the value of their chosen career: $\tilde{u}^k_{i,j=j_i^{k*}}\left( F_{i}\right)$, and the realized value of their chosen career track: $u^k_{i,j=j_i^{k*}}=v_{j=j_i^{k*}}+\epsilon_{i,j=j_i^{k*}}^k$.

# %% [markdown]
# Chosen values will be: <br>
# $i\in\left\{1,2\dots,N\right\}, N=10$ <br>
# $F_i = i$<br>
# So there are 10 graduates. The first has 1 friend in each career, the second has 2 friends, ... the tenth has 10 friends.

# %% [markdown]
# **Question 2:** Simulate and visualize: For each type of graduate, $i$, the share of graduates choosing each career, the average subjective expected utility of the graduates, and the average ex post realized utility given their choice. <br>
# That is, calculate and visualize: <br>
# $$
# \begin{align*}
#     \frac{1}{K} \sum_{k=1}^{K} \mathbb{I}\left\{ j=j_i^{k*} \right\}  \;\forall j\in\left\{1,2,\dots,J\right\}
# \end{align*}
# $$
# $$
# \begin{align*}
#     \frac{1}{K} \sum_{k=1}^{K} \tilde{u}^k_{ij=j_i^{k*}}\left( F_{i}\right)
# \end{align*}
# $$
# And
# $$
# \begin{align*}
#     \frac{1}{K} \sum_{k=1}^{K} u^k_{ij=j_i^{k*}}
# \end{align*}
# $$
# For each graduate $i$.

# %%
# Write your answer here

# %% [markdown]
# After a year of working in their career, the graduates learn $u^k_{ij}$ for their chosen job $j_i^{k*}$ perfectly. <br>
# The can switch to one of the two remaining careers, for which they have the same prior as before, but it will now include a switching cost of $c$ which is known.
# Their new priors can be written as:
# $$
# \tilde{u}^{k,2}_{ij}\left( F_{i}\right) = \begin{cases}
#             \tilde{u}^k_{ij}\left( F_{i}\right)-c & \text{if } j \neq j_i^{k*} \\
#             u_{ij=j_i^{k*}} & \text{if } j = j_i^{k*}
#         \end{cases}
# $$

# %% [markdown]
# We will set $c=1$.

# %% [markdown]
# Their realized utility will be: <br>
# $$
# u^{k,2}_{ij}= \begin{cases}
#             u_{ij}^k -c & \text{if } j \neq j_i^{k*} \\
#             u_{ij=j_i^{k*}} & \text{if } j = j_i^{k*}
#         \end{cases}
# $$

# %% [markdown]
# **Question 3:** Following the same approach as in question 2, find the new optimal career choice for each $i$, $k$. Then for each $i$, calculate the average subjective expected utility from their new optimal career choice, and the ex post realized utility of that career. Also, for each $i$, calculate the share of graduates that chooses to switch careers, conditional on which career they chose in the first year. <br>

# %%
# write your answer here

# %% [markdown]
# ## 3. <a id='toc3_'></a>[Problem 3: Barycentric interpolation](#toc0_)

# %% [markdown]
# **Problem:** We have a set of random points in the unit square,
#
# $$
# \mathcal{X} = \{(x_1,x_2)\,|\,x_1\sim\mathcal{U}(0,1),x_2\sim\mathcal{U}(0,1)\}.
# $$
#
# For these points, we know the value of some function $f(x_1,x_2)$,
#
# $$
# \mathcal{F} = \{f(x_1,x_2) \,|\, (x_1,x_2) \in \mathcal{X}\}.
# $$
#
# Now we want to approximate the value $f(y_1,y_2)$ for some  $y=(y_1,y_2)$, where $y_1\sim\mathcal{U}(0,1)$ and $y_2\sim\mathcal{U}(0,1)$.
#
# **Building block I**
#
# For an arbitrary triangle $ABC$ and a point $y$, define the so-called barycentric coordinates as:
#
# $$
# \begin{align*}
#   r^{ABC}_1 &= \frac{(B_2-C_2)(y_1-C_1) + (C_1-B_1)(y_2-C_2)}{(B_2-C_2)(A_1-C_1) + (C_1-B_1)(A_2-C_2)} \\
#   r^{ABC}_2 &= \frac{(C_2-A_2)(y_1-C_1) + (A_1-C_1)(y_2-C_2)}{(B_2-C_2)(A_1-C_1) + (C_1-B_1)(A_2-C_2)} \\
#   r^{ABC}_3 &= 1 - r_1 - r_2.
# \end{align*}
# $$
#
# If $r^{ABC}_1 \in [0,1]$, $r^{ABC}_2 \in [0,1]$, and $r^{ABC}_3 \in [0,1]$, then the point is inside the triangle.
#
# We always have $y = r^{ABC}_1 A + r^{ABC}_2 B + r^{ABC}_3 C$.
#
# **Building block II**
#
# Define the following points:
#
# $$
# \begin{align*}
# A&=\arg\min_{(x_{1},x_{2})\in\mathcal{X}}\sqrt{\left(x_{1}-y_{1}\right)^{2}+\left(x_{2}-y_{2}\right)^{2}}\text{ s.t. }x_{1}>y_{1}\text{ and }x_{2}>y_{2}\\
# B&=\arg\min_{(x_{1},x_{2})\in\mathcal{X}}\sqrt{\left(x_{1}-y_{1}\right)^{2}+\left(x_{2}-y_{2}\right)^{2}}\text{ s.t. }x_{1}>y_{1}\text{ and }x_{2}<y_{2}\\
# C&=\arg\min_{(x_{1},x_{2})\in\mathcal{X}}\sqrt{\left(x_{1}-y_{1}\right)^{2}+\left(x_{2}-y_{2}\right)^{2}}\text{ s.t. }x_{1}<y_{1}\text{ and }x_{2}<y_{2}\\
# D&=\arg\min_{(x_{1},x_{2})\in\mathcal{X}}\sqrt{\left(x_{1}-y_{1}\right)^{2}+\left(x_{2}-y_{2}\right)^{2}}\text{ s.t. }x_{1}<y_{1}\text{ and }x_{2}>y_{2}.
# \end{align*}
# $$
#
# **Algorithm:**
#
# 1. Compute $A$, $B$, $C$, and $D$. If not possible return `NaN`.
# 1. If $y$ is inside the triangle $ABC$ return $r^{ABC}_1 f(A) + r^{ABC}_2 f(B) + r^{ABC}_3 f(C)$.
# 1. If $y$ is inside the triangle $CDA$ return $r^{CDA}_1 f(C) + r^{CDA}_2 f(D) + r^{CDA}_3 f(A)$.
# 1. Return `NaN`.

# %% [markdown]
# **Sample:**

# %%
rng = np.random.default_rng(2024)

X = rng.uniform(size=(50,2))
y = rng.uniform(size=(2,))

# %% [markdown]
# **Questions 1:** Find $A$, $B$, $C$ and $D$. Illustrate these together with $X$, $y$ and the triangles $ABC$ and $CDA$.

# %%
# write your answer here

# %% [markdown]
# **Question 2:** Compute the barycentric coordinates of the point $y$ with respect to the triangles $ABC$ and $CDA$. Which triangle is $y$ located inside?

# %%
# write your answer here

# %% [markdown]
# Now consider the function:
# $$
# f(x_1,x_2) = x_1 \cdot x_2
# $$

# %%
f = lambda x: x[0]*x[1]
F = np.array([f(x) for x in X])

# %% [markdown]
# **Question 3:** Compute the approximation of $f(y)$ using the full algorithm. Compare with the true value.

# %%
# write your answer here

# %% [markdown]
# **Question 4:** Repeat question 3 for all points in the set $Y$.

# %%
Y = [(0.2,0.2),(0.8,0.2),(0.8,0.8),(0.8,0.2),(0.5,0.5)]

# %%
# write your answer here
